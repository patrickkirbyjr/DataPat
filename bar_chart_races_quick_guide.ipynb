# %% [markdown]
# <a href="https://colab.research.google.com/github/patrickkirbyjr/DataPat/blob/main/bar_chart_races_quick_guide.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # How to Make Bar Chart Races in Python - Quick Guide

# %%
# install bar_chart_race library
# !pip install bar_chart_race

# %%
# import libraries
import bar_chart_race as bcr
import pandas as pd
from IPython.display import Video

# %%
# import dataset (built-in bcr dataset)
df = bcr.load_dataset("covid19")
df.head()

# %%
# create the bar chart race
bcr.bar_chart_race(
    df=df,
    filename="bar_chart_race.mp4",
    n_bars=10,
    title="Top 10 COVID-19 Cases by Country"
)

# %%
# display the video
Video("bar_chart_race.mp4", embed=True, width=600)

# %% [markdown]
# # How do I download my bar chart race?
#
# <---- Click the folder icon
